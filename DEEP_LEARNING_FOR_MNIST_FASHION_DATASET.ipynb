# %%
#DEEP LEARNING PROJECT FOR MNIST FASHION DATASET
#STEPS IN PROJECT:
#1. importing the dataset from keras.
#2.splitting the data.
#3.plotting the data for example 12 images.
#4.finding the shape of data and reshaping it.
#5.normalising the model by dividing it by 255.
#6.importing the packages for buiding the model.
#7.build the model and compile it.
#8.display the summary of the model.
#9.fit the model with tran data set.
#10.display the accuracy and loss using score variable.
#11.making predictions for test elements
#12.creating a dictionary which shows the resultant answer of that value
#13.plotting the result

# %%
#1.IMPORTING DATASET
from keras.datasets import fashion_mnist
data = fashion_mnist.load_data()

# %%
# 2.SPLITTING THE DATA INTO TRAINIG AND TESTING DATA
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()

# %%
#3.PLOTTING THE DATA FOR EXAMPLE
import matplotlib.pyplot as plt
plt.subplot(221)
plt.imshow(X_train[0], cmap=plt.get_cmap('gray'))
plt.subplot(222)
plt.imshow(X_train[1], cmap=plt.get_cmap('gray'))
plt.subplot(223)
plt.imshow(X_train[2], cmap=plt.get_cmap('gray'))
plt.subplot(224)
plt.imshow(X_train[3], cmap=plt.get_cmap('gray'))
# show the plot
plt.show()

# %%
#3.PLOTTING THE DATA FOR EXAMPLE
plt.subplot(221)
plt.imshow(X_train[4], cmap=plt.get_cmap('gray'))
plt.subplot(222)
plt.imshow(X_train[5], cmap=plt.get_cmap('gray'))
plt.subplot(223)
plt.imshow(X_train[6], cmap=plt.get_cmap('gray'))
plt.subplot(224)
plt.imshow(X_train[7], cmap=plt.get_cmap('gray'))
# show the plot
plt.show()

# %%
#3.PLOTTING THE DATA FOR EXAMPLE
plt.subplot(221)
plt.imshow(X_train[8], cmap=plt.get_cmap('gray'))
plt.subplot(222)
plt.imshow(X_train[9], cmap=plt.get_cmap('gray'))
plt.subplot(223)
plt.imshow(X_train[10], cmap=plt.get_cmap('gray'))
plt.subplot(224)
plt.imshow(X_train[11], cmap=plt.get_cmap('gray'))
# show the plot
plt.show()

# %%
#4.FINDING THE SHAPE OF DATA USING SHAPE FUNCTION
X_train[0].shape
# Out:
# (28, 28)

# %%
#4.RESHAPING THE DATA INTO 28*28 MATRIX AND CONVERTING THE DATATYPE AS FLOAT 
X_train = X_train.reshape((X_train.shape[0], 28*28)).astype('float32')
X_test = X_test.reshape((X_test.shape[0], 28*28)).astype('float32')

# %%
#5. Normalizing values from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255

# %%
from keras.utils import np_utils

Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)
num_classes = Y_test.shape[1]

# %%
#6.IMPORTING PACKAGES FOR BUILDING A DEEP LEARNING MODEL
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
#7. BUILDING THE MODEL
model = Sequential()
model.add(Dense(32, input_dim = 28*28, activation='relu'))  ## hidden layer 1
model.add(Dense(64, activation='relu'))  ## hidden layer 2
model.add(Dense(128, activation='relu'))   ## hidden layer 3
model.add(Dense(256, activation='relu'))   ## hidden layer 4
model.add(Dense(512, activation='relu'))   ## hidden layer 5
model.add(Dense(1024, activation='relu'))   ## hidden layer 6
model.add(Dense(10, activation='softmax'))  ## output layer, 10 = number of classes

# %% [markdown]
# ![neural.png](data:image/png;base64,...)

# %%
#7.COMPILE THE MODEL
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#8.PRINT THE SUMMARY OF THE MODEL
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_12 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_17 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# ...

# %%
#9.FIT THE MODEL
model.fit(X_train, Y_train, validation_split=0.2 , epochs=50, batch_size=100)
# Out:
# Epoch 1/50
# 480/480 [==============================] - 9s 18ms/step - loss: 0.8150 - accuracy: 0.6930 - val_loss: 0.4415 - val_accuracy: 0.8379
# Epoch 2/50
# 480/480 [==============================] - 8s 17ms/step - loss: 0.4185 - accuracy: 0.8474 - val_loss: 0.4192 - val_accuracy: 0.8474
# Epoch 3/50
# 480/480 [==============================] - 8s 18ms/step - loss: 0.3699 - accuracy: 0.8671 - val_loss: 0.4269 - val_accuracy: 0.8518
# Epoch 4/50
# 480/480 [==============================] - 8s 17ms/step - loss: 0.3547 - accuracy: 0.8701 - val_loss: 0.3650 - val_accuracy: 0.8711
# Epoch 5/50
# 480/480 [==============================] - 8s 17ms/step - loss: 0.3274 - accuracy: 0.8793 - val_loss: 0.3497 - val_accuracy: 0.8723
# Epoch 6/50
# 480/480 [==============================] - 8s 17ms/step - loss: 0.3087 - accuracy: 0.8873 - val_loss: 0.3454 - val_accuracy: 0.8737
# Epoch 7/50
# ...

# %%
#10.RETURN THE LOSS AND ACCURACY PERCENT
scores = model.evaluate(X_test, Y_test)
print(scores)   ## returns loss and accuracy
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5973 - accuracy: 0.8795
# [0.5973452925682068, 0.8794999718666077]

# %%
#11.MAKING PREDICTIONS FOR TEST ELEMENTS
predictions = model.predict(X_test)
label=[]
for pred in predictions:
  max_val = max(pred)
  for (i,p) in enumerate(pred):
    if(p==max_val):
      label.append(i)

# %%
#12.CREATING DICTIONARY WHICH DEPICTS THE PREDICTION
answer={0:'T-shirt/top',1:'Trouser/Pant',2:'Pullover',3:'Dress',4:'Coat',5:'Sandal',6:'Shirt',7:'Sneaker',8:'Bag',9:'Ankle Boot'}

# %%
#13.PLOTTING THE ANSWER 
plt.figure(figsize=(10,10))
plt.subplot(221)
plt.imshow(X_test[0].reshape(28,28), cmap=plt.get_cmap('gray'))
plt.title(f'PREDICTED: {answer[label[0]]}')
plt.subplot(222)
plt.imshow(X_test[1].reshape(28,28), cmap=plt.get_cmap('gray'))
plt.title(f'PREDICTED: {answer[label[1]]}')
plt.subplot(223)
plt.imshow(X_test[2].reshape(28,28), cmap=plt.get_cmap('gray'))
plt.title(f'PREDICTED: {answer[label[2]]}')
plt.subplot(224)
plt.imshow(X_test[3].reshape(28,28), cmap=plt.get_cmap('gray'))
plt.title(f'PREDICTED: {answer[label[3]]}')
# show the plot
plt.show()
